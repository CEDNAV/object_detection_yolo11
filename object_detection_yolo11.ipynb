# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.6/911.6 kB 23.7 MB/s eta 0:00:00
# ...

# %%
pip install ultralytics

# %%
from ultralytics import YOLO
print("YOLOv8 instalado correctamente")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv8 instalado correctamente

# %%
# Cargar el modelo YOLOv8 preentrenado
model = YOLO('yolo11n.pt')  # Puedes usar otros modelos: yolov8s.pt, yolov8m.pt, etc.
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 106MB/s]

# %%
from google.colab import files

# Sube el video
uploaded = files.upload()

# Verifica los archivos cargados
for filename in uploaded.keys():
    print(f"Cargado: {filename}")
# Out:
#      <input type="file" id="files-bd5828f1-d42c-4cbe-aa8e-d1860330e057" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd5828f1-d42c-4cbe-aa8e-d1860330e057">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Detectar objetos en el video
input_video = '/content/CANAL_SUEZ.mp4'  # Cambia este nombre por el de tu archivo cargado
output_video = 'resultado.mp4'  # Nombre del archivo de salida

# Ejecutar detección
results = model.predict(source=input_video, save=True, save_txt=True)

# El archivo procesado se guarda automáticamente en la carpeta 'runs/detect'
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/10202) /content/CANAL_SUEZ.mp4: 384x640 4 boats, 100.2ms
# video 1/1 (frame 2/10202) /content/CANAL_SUEZ.mp4: 384x640 4 boats, 11.5ms
# video 1/1 (frame 3/10202) /content/CANAL_SUEZ.mp4: 384x640 3 boats, 11.2ms
# video 1/1 (frame 4/10202) /content/CANAL_SUEZ.mp4: 384x640 3 boats, 10.4ms
# video 1/1 (frame 5/10202) /content/CANAL_SUEZ.mp4: 384x640 3 boats, 10.1ms
# ...
